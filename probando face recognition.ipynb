# %%
# !pip install face_recognition
# !apt-get -qq install -y face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.1 MB 30 kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566186 sha256=397fa7b223a546e8b606a7dbe0d4c3e92075bed3713afcb888b3d2cb14666499
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# ...
# E: Unable to locate package face_recognition

# %%
import face_recognition
import numpy as np

# %%
image = face_recognition.load_image_file("rostrocortado25.jpg")
image2 = face_recognition.load_image_file("rostrocompleto20.jpg")

print(image.shape)


face_locations = face_recognition.face_locations(image2)
print(face_locations)

face_encoding = face_recognition.face_encodings(image)[0]
face_encoding2 = face_recognition.face_encodings(image2)[0]

print(face_encoding.shape)

print("-----------------------")
#print("I found {} face(s) in this photograph.".format(len(face_locations)))

for face_location in face_locations:

    # Print the location of each face in this image
    top, right, bottom, left = face_location
    print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

    # You can access the actual face itself like this:
    # face_image = image[top:bottom, left:right]
    # pil_image = Image.fromarray(face_image)
    # pil_image.show()

results = face_recognition.compare_faces([face_encoding], face_encoding2)

print(results)
# Out:
# (325, 325, 3)
# [(63, 526, 384, 205)]
# (128,)
# -----------------------
# A face is located at pixel location Top: 63, Left: 205, Bottom: 384, Right: 526
# [True]
